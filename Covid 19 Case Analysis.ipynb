# %%
# Importing Libraries like pandas ,seaborn,matplotlib.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
# Dataset

# %%
df
# Out:
#     sno                                state_name  active  positive     cured
# 0     1               Andaman and Nicobar Islands       0     10766     10637  \
# 1     2                            Andhra Pradesh       0   2340672   2325939
# 2     3                         Arunachal Pradesh       0     67046     66750
# 3     4                                     Assam       7    746150    738108
# 4     5                                     Bihar       1    855260    842945
# 5     6                                Chandigarh       2    100691     99504
# 6     7                              Chhattisgarh       3   1187686   1173493
# 7     8  Dadra and Nagar Haveli and Daman and Diu       0     11592     11588
# 8     9                                     Delhi       5   2040785   2014115
# 9    10                                      Goa*      10    263313    259289
# 10   11                                   Gujarat      11   1291358   1280268
# 11   12                                   Haryana      27   1078878   1068097
# 12   13                          Himachal Pradesh      13    322835    318582
# 13   14                         Jammu and Kashmir       2    482019    477225
# 14   15                                 Jharkhand       0    443824    438490
# 15   16                                 Karnataka      16   4088651   4048278
# 16   17                                 Kerala***    1032   6907018   6834042
# 17   18                                    Ladakh       0     29587     29356
# 18   19                               Lakshadweep       0     11415     11363
# 19   20                            Madhya Pradesh       3   1056351   1045562
# 20   21                               Maharashtra      75   8169904   8021273
# 21   22                                   Manipur      18    139973    137806
# 22   23                                 Meghalaya       0     96954     95326
# 23   24                                   Mizoram       7    239551    238811
# 24   25                                  Nagaland       0     36029     35247
# 25   26                                    Odisha      14   1348288   1339006
# 26   27                                Puducherry       2    177544    175561
# 27   28                                  Punjab**       3    793629    773060
# 28   29                                 Rajasthan       0   1326457   1316721
# 29   30                                    Sikkim       4     44866     44362
# 30   31                                Tamil Nadu       7   3610606   3572518
# 31   32                                 Telangana       9    844367    840247
# 32   33                                   Tripura      20    108342    107381
# 33   34                               Uttarakhand       5    452550    444777
# 34   35                             Uttar Pradesh      67   2145406   2121632
# 35   36                               West Bengal     100   2125461   2103809
# 36   37                                              1463  44995824  44461168
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille
# 0      129           0         10766      10637        129                   \
# 1    14733           0       2340672    2325939      14733
# 2      296           0         67046      66750        296
# 3     8035           7        746150     738108       8035
# 4    12314           1        855260     842945      12314
# 5     1185           1        100691      99505       1185
# 6    14190           2       1187686    1173494      14190
# 7        4           0         11592      11588          4
# 8    26665           8       2040788    2014115      26665
# 9     4014           7        263313     259292       4014
# 10   11079          11       1291358    1280268      11079
# 11   10754          27       1078878    1068097      10754
# 12    4240          10        322838     318588       4240
# 13    4792           2        482019     477225       4792
# 14    5334           0        443824     438490       5334
# 15   40357          16       4088652    4048279      40357
# 16   71944        1031       6907019    6834044      71944
# 17     231           0         29587      29356        231
# 18      52           0         11415      11363         52
# 19   10786           3       1056351    1045562      10786
# 20  148556          79       8169917    8021282     148556
# 21    2149          18        139973     137806       2149
# 22    1628           0         96954      95326       1628
# 23     733           6        239552     238812        734
# 24     782           0         36029      35247        782
# 25    9215          13       1348288    1339007       9215
# 26    1981           3        177545     175561       1981
# 27   19338           4        793630     773060      19338
# 28    9736           0       1326457    1316721       9736
# 29     500           4         44866      44362        500
# 30   38081           6       3610607    3572520      38081
# 31    4111          10        844368     840247       4111
# 32     941          19        108343     107383        941
# 33    7768           3        452550     444779       7768
# 34   23707          67       2145406    2121632      23707
# 35   21552          96       2125466    2103818      21552
# 36  531912        1454      44995856   44461208     531913
#
#    total  state_code  actualdeath24hrs
# 0                 35                 0
# 1                 28                 0
# 2                 12                 0
# 3                 18                 0
# 4                 10                 0
# 5                  4                 0
# 6                 22                 0
# 7                 26                 0
# 8                  7                 0
# 9                 30                 0
# 10                24                 0
# 11                 6                 0
# 12                 2                 0
# 13                 1                 0
# 14                20                 0
# 15                29                 0
# 16                32                 0
# 17                37                 0
# 18                31                 0
# 19                23                 0
# 20                27                 0
# 21                14                 0
# 22                17                 0
# 23     1          15                 1
# 24                13                 0
# 25                21                 0
# 26                34                 0
# 27                 3                 0
# 28                 8                 0
# 29                11                 0
# 30                33                 0
# 31                36                 0
# 32                16                 0
# 33                 5                 0
# 34                 9                 0
# 35                19                 0
# 36     1           0                 1

# %% [markdown]
# # DATA UNDERSTANDING

# %%
df.shape
# no of columns and rows
# Out:
# (37, 14)

# %%
df.isnull().sum()
#
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# actualdeath24hrs    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     int64
#  13  actualdeath24hrs  37 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 4.2+ KB

# %%
df.describe()
# Out:
#              sno       active      positive         cured          death
# count  37.000000    37.000000  3.700000e+01  3.700000e+01      37.000000  \
# mean   19.000000    79.081081  2.432207e+06  2.403306e+06   28752.000000
# std    10.824355   288.518474  7.418521e+06  7.329444e+06   89151.137534
# min     1.000000     0.000000  1.076600e+04  1.063700e+04       4.000000
# 25%    10.000000     0.000000  1.083420e+05  1.073810e+05    1185.000000
# 50%    19.000000     5.000000  7.461500e+05  7.381080e+05    7768.000000
# 75%    28.000000    14.000000  1.348288e+06  1.339006e+06   14733.000000
# max    37.000000  1463.000000  4.499582e+07  4.446117e+07  531912.000000
#
#         new_active  new_positive     new_cured      new_death  state_code
# count    37.000000  3.700000e+01  3.700000e+01      37.000000   37.000000  \
# mean     78.594595  2.432208e+06  2.403309e+06   28752.054054   18.324324
# std     287.273240  7.418527e+06  7.329450e+06   89151.285579   11.212726
# min       0.000000  1.076600e+04  1.063700e+04       4.000000    0.000000
# 25%       0.000000  1.083430e+05  1.073830e+05    1185.000000    9.000000
# 50%       4.000000  7.461500e+05  7.381080e+05    7768.000000   18.000000
# 75%      13.000000  1.348288e+06  1.339007e+06   14733.000000   28.000000
# max    1454.000000  4.499586e+07  4.446121e+07  531913.000000   37.000000
#
#        actualdeath24hrs
# count         37.000000
# mean           0.054054
# std            0.229243
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            0.000000
# max            1.000000

# %%
df.keys()
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code', 'actualdeath24hrs'],
#       dtype='object')

# %%
df.nunique()
# Out:
# sno                 37
# state_name          37
# active              21
# positive            37
# cured               37
# death               37
# new_active          20
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     1
# total                2
# state_code          37
# actualdeath24hrs     2
# dtype: int64

# %%
df.tail()
# Out:
#     sno     state_name  active  positive     cured   death  new_active
# 32   33        Tripura      20    108342    107381     941          19  \
# 33   34    Uttarakhand       5    452550    444777    7768           3
# 34   35  Uttar Pradesh      67   2145406   2121632   23707          67
# 35   36    West Bengal     100   2125461   2103809   21552          96
# 36   37                   1463  44995824  44461168  531912        1454
#
#     new_positive  new_cured  new_death death_reconsille total  state_code
# 32        108343     107383        941                                 16  \
# 33        452550     444779       7768                                  5
# 34       2145406    2121632      23707                                  9
# 35       2125466    2103818      21552                                 19
# 36      44995856   44461208     531913                      1           0
#
#     actualdeath24hrs
# 32                 0
# 33                 0
# 34                 0
# 35                 0
# 36                 1

# %%
df=df.iloc[:36]

# %%
df
# so this is the data set in which we are going to work
# Out:
#     sno                                state_name  active  positive    cured
# 0     1               Andaman and Nicobar Islands       0     10766    10637  \
# 1     2                            Andhra Pradesh       0   2340672  2325939
# 2     3                         Arunachal Pradesh       0     67046    66750
# 3     4                                     Assam       7    746150   738108
# 4     5                                     Bihar       1    855260   842945
# 5     6                                Chandigarh       2    100691    99504
# 6     7                              Chhattisgarh       3   1187686  1173493
# 7     8  Dadra and Nagar Haveli and Daman and Diu       0     11592    11588
# 8     9                                     Delhi       5   2040785  2014115
# 9    10                                      Goa*      10    263313   259289
# 10   11                                   Gujarat      11   1291358  1280268
# 11   12                                   Haryana      27   1078878  1068097
# 12   13                          Himachal Pradesh      13    322835   318582
# 13   14                         Jammu and Kashmir       2    482019   477225
# 14   15                                 Jharkhand       0    443824   438490
# 15   16                                 Karnataka      16   4088651  4048278
# 16   17                                 Kerala***    1032   6907018  6834042
# 17   18                                    Ladakh       0     29587    29356
# 18   19                               Lakshadweep       0     11415    11363
# 19   20                            Madhya Pradesh       3   1056351  1045562
# 20   21                               Maharashtra      75   8169904  8021273
# 21   22                                   Manipur      18    139973   137806
# 22   23                                 Meghalaya       0     96954    95326
# 23   24                                   Mizoram       7    239551   238811
# 24   25                                  Nagaland       0     36029    35247
# 25   26                                    Odisha      14   1348288  1339006
# 26   27                                Puducherry       2    177544   175561
# 27   28                                  Punjab**       3    793629   773060
# 28   29                                 Rajasthan       0   1326457  1316721
# 29   30                                    Sikkim       4     44866    44362
# 30   31                                Tamil Nadu       7   3610606  3572518
# 31   32                                 Telangana       9    844367   840247
# 32   33                                   Tripura      20    108342   107381
# 33   34                               Uttarakhand       5    452550   444777
# 34   35                             Uttar Pradesh      67   2145406  2121632
# 35   36                               West Bengal     100   2125461  2103809
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille
# 0      129           0         10766      10637        129                   \
# 1    14733           0       2340672    2325939      14733
# 2      296           0         67046      66750        296
# 3     8035           7        746150     738108       8035
# 4    12314           1        855260     842945      12314
# 5     1185           1        100691      99505       1185
# 6    14190           2       1187686    1173494      14190
# 7        4           0         11592      11588          4
# 8    26665           8       2040788    2014115      26665
# 9     4014           7        263313     259292       4014
# 10   11079          11       1291358    1280268      11079
# 11   10754          27       1078878    1068097      10754
# 12    4240          10        322838     318588       4240
# 13    4792           2        482019     477225       4792
# 14    5334           0        443824     438490       5334
# 15   40357          16       4088652    4048279      40357
# 16   71944        1031       6907019    6834044      71944
# 17     231           0         29587      29356        231
# 18      52           0         11415      11363         52
# 19   10786           3       1056351    1045562      10786
# 20  148556          79       8169917    8021282     148556
# 21    2149          18        139973     137806       2149
# 22    1628           0         96954      95326       1628
# 23     733           6        239552     238812        734
# 24     782           0         36029      35247        782
# 25    9215          13       1348288    1339007       9215
# 26    1981           3        177545     175561       1981
# 27   19338           4        793630     773060      19338
# 28    9736           0       1326457    1316721       9736
# 29     500           4         44866      44362        500
# 30   38081           6       3610607    3572520      38081
# 31    4111          10        844368     840247       4111
# 32     941          19        108343     107383        941
# 33    7768           3        452550     444779       7768
# 34   23707          67       2145406    2121632      23707
# 35   21552          96       2125466    2103818      21552
#
#    total  state_code  actualdeath24hrs
# 0                 35                 0
# 1                 28                 0
# 2                 12                 0
# 3                 18                 0
# 4                 10                 0
# 5                  4                 0
# 6                 22                 0
# 7                 26                 0
# 8                  7                 0
# 9                 30                 0
# 10                24                 0
# 11                 6                 0
# 12                 2                 0
# 13                 1                 0
# 14                20                 0
# 15                29                 0
# 16                32                 0
# 17                37                 0
# 18                31                 0
# 19                23                 0
# 20                27                 0
# 21                14                 0
# 22                17                 0
# 23     1          15                 1
# 24                13                 0
# 25                21                 0
# 26                34                 0
# 27                 3                 0
# 28                 8                 0
# 29                11                 0
# 30                33                 0
# 31                36                 0
# 32                16                 0
# 33                 5                 0
# 34                 9                 0
# 35                19                 0

# %%
df['active'].sum(axis=0)
# ouput = 1463
# Out:
# 1463

# %%
df['positive'].sum(axis=0)
# output = 44995824
# Out:
# 44995824

# %%
df['cured'].sum(axis=0)
# output = 44461168
# Out:
# 44461168

# %%
df['death'].sum(axis=0)
#output = 531912
# Out:
# 531912

# %%
df['new_active'].sum(axis=0)
#output=1454
# Out:
# 1454

# %%
df['new_positive'].sum(axis=0)
# output = 44995856
# Out:
# 44995856

# %%
df['new_cured'].sum(axis=0)
#output = 44461208
# Out:
# 44461208

# %%
df['new_death'].sum(axis=0)
# output = 531913
# Out:
# 531913

# %% [markdown]
# # NOW, DATA VISUALISATION

# %%
sns.pairplot(data=df)
# plotting scatter plots of all data using pairplot

# %%
cases_df=df.sum

# %%
cases_df
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of     sno                                state_name  active  positive    cured
# 0     1               Andaman and Nicobar Islands       0     10766    10637  \
# 1     2                            Andhra Pradesh       0   2340672  2325939
# 2     3                         Arunachal Pradesh       0     67046    66750
# 3     4                                     Assam       7    746150   738108
# 4     5                                     Bihar       1    855260   842945
# 5     6                                Chandigarh       2    100691    99504
# 6     7                              Chhattisgarh       3   1187686  1173493
# 7     8  Dadra and Nagar Haveli and Daman and Diu       0     11592    11588
# 8     9                                     Delhi       5   2040785  2014115
# 9    10                                      Goa*      10    263313   259289
# 10   11                                   Gujarat      11   1291358  1280268
# 11   12                                   Haryana      27   1078878  1068097
# 12   13                          Himachal Pradesh      13    322835   318582
# 13   14                         Jammu and Kashmir       2    482019   477225
# 14   15                                 Jharkhand       0    443824   438490
# 15   16                                 Karnataka      16   4088651  4048278
# 16   17                                 Kerala***    1032   6907018  6834042
# 17   18                                    Ladakh       0     29587    29356
# 18   19                               Lakshadweep       0     11415    11363
# 19   20                            Madhya Pradesh       3   1056351  1045562
# 20   21                               Maharashtra      75   8169904  8021273
# 21   22                                   Manipur      18    139973   137806
# 22   23                                 Meghalaya       0     96954    95326
# 23   24                                   Mizoram       7    239551   238811
# 24   25                                  Nagaland       0     36029    35247
# 25   26                                    Odisha      14   1348288  1339006
# 26   27                                Puducherry       2    177544   175561
# 27   28                                  Punjab**       3    793629   773060
# 28   29                                 Rajasthan       0   1326457  1316721
# 29   30                                    Sikkim       4     44866    44362
# 30   31                                Tamil Nadu       7   3610606  3572518
# 31   32                                 Telangana       9    844367   840247
# 32   33                                   Tripura      20    108342   107381
# 33   34                               Uttarakhand       5    452550   444777
# 34   35                             Uttar Pradesh      67   2145406  2121632
# 35   36                               West Bengal     100   2125461  2103809
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille
# 0      129           0         10766      10637        129                   \
# 1    14733           0       2340672    2325939      14733
# 2      296           0         67046      66750        296
# 3     8035           7        746150     738108       8035
# 4    12314           1        855260     842945      12314
# 5     1185           1        100691      99505       1185
# 6    14190           2       1187686    1173494      14190
# 7        4           0         11592      11588          4
# 8    26665           8       2040788    2014115      26665
# 9     4014           7        263313     259292       4014
# 10   11079          11       1291358    1280268      11079
# 11   10754          27       1078878    1068097      10754
# 12    4240          10        322838     318588       4240
# 13    4792           2        482019     477225       4792
# 14    5334           0        443824     438490       5334
# 15   40357          16       4088652    4048279      40357
# 16   71944        1031       6907019    6834044      71944
# 17     231           0         29587      29356        231
# 18      52           0         11415      11363         52
# 19   10786           3       1056351    1045562      10786
# 20  148556          79       8169917    8021282     148556
# 21    2149          18        139973     137806       2149
# 22    1628           0         96954      95326       1628
# 23     733           6        239552     238812        734
# 24     782           0         36029      35247        782
# 25    9215          13       1348288    1339007       9215
# 26    1981           3        177545     175561       1981
# 27   19338           4        793630     773060      19338
# 28    9736           0       1326457    1316721       9736
# 29     500           4         44866      44362        500
# 30   38081           6       3610607    3572520      38081
# 31    4111          10        844368     840247       4111
# 32     941          19        108343     107383        941
# 33    7768           3        452550     444779       7768
# 34   23707          67       2145406    2121632      23707
# 35   21552          96       2125466    2103818      21552
#
#    total  state_code  actualdeath24hrs
# 0                 35                 0
# 1                 28                 0
# 2                 12                 0
# 3                 18                 0
# 4                 10                 0
# 5                  4                 0
# 6                 22                 0
# 7                 26                 0
# 8                  7                 0
# 9                 30                 0
# 10                24                 0
# 11                 6                 0
# 12                 2                 0
# 13                 1                 0
# 14                20                 0
# 15                29                 0
# 16                32                 0
# 17                37                 0
# 18                31                 0
# 19                23                 0
# 20                27                 0
# 21                14                 0
# 22                17                 0
# 23     1          15                 1
# 24                13                 0
# 25                21                 0
# 26                34                 0
# 27                 3                 0
# 28                 8                 0
# 29                11                 0
# 30                33                 0
# 31                36                 0
# 32                16                 0
# 33                 5                 0
# 34                 9                 0
# 35                19                 0  >

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)
# Dropping unnecessary columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 cases_df.drop(['sno','state_name','state_code'],inplace=True)
#       2 # Dropping unnecessary columns
#
# AttributeError: 'function' object has no attribute 'drop'

# %%
cases_df

# %%
my_data = [1460,44995824,44461168,531912]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','green','red','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [1454,44995556,44461208,531913]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightgreen','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [1460,44995824,44461168,531912,1454,44995556,44461208,531913]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['black','navajowhite','darkblue','grey','lightblue','yellow','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their death cases.
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);
# The below visualization shows us that high number of positive cases can be seen in Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);
# The visualization below shows us that high number of people have cured in the state of Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);
# The below visualization shows us that high number of deaths taking place in the state of Maharashtra followed by Tamilnadu and karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);
# The following visualization shows us the total number of new cases and kerela has the high number of new active cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);
# The following visualization shows us the total number of new positive cases and Maharashtra has the high number of new positive cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);
# The following visualization shows us the total number of new cured cases and Maharashtra has the high number of new cured cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);
# Maharashtra has the highest new death rates in India followed by Karnataka

# %%
df.columns

# %%
df.drop(['sno','state_code',],axis=1,inplace=True)

# %%
df.head(5)
# Out:
#    sno                   state_name  active  positive    cured  death
# 0    1  Andaman and Nicobar Islands       0     10766    10637    129  \
# 1    2               Andhra Pradesh       0   2340672  2325939  14733
# 2    3            Arunachal Pradesh       0     67046    66750    296
# 3    4                        Assam       7    746150   738108   8035
# 4    5                        Bihar       1    855260   842945  12314
#
#    new_active  new_positive  new_cured  new_death death_reconsille total
# 0           0         10766      10637        129                         \
# 1           0       2340672    2325939      14733
# 2           0         67046      66750        296
# 3           7        746150     738108       8035
# 4           1        855260     842945      12314
#
#    state_code  actualdeath24hrs
# 0          35                 0
# 1          28                 0
# 2          12                 0
# 3          18                 0
# 4          10                 0

# %%
df=df.set_index('state_name')

# %%
df.head(10)
# Out:
#                                           sno  active  positive    cured
# state_name
# Andaman and Nicobar Islands                 1       0     10766    10637  \
# Andhra Pradesh                              2       0   2340672  2325939
# Arunachal Pradesh                           3       0     67046    66750
# Assam                                       4       7    746150   738108
# Bihar                                       5       1    855260   842945
# Chandigarh                                  6       2    100691    99504
# Chhattisgarh                                7       3   1187686  1173493
# Dadra and Nagar Haveli and Daman and Diu    8       0     11592    11588
# Delhi                                       9       5   2040785  2014115
# Goa*                                       10      10    263313   259289
#
#                                           death  new_active  new_positive
# state_name
# Andaman and Nicobar Islands                 129           0         10766  \
# Andhra Pradesh                            14733           0       2340672
# Arunachal Pradesh                           296           0         67046
# Assam                                      8035           7        746150
# Bihar                                     12314           1        855260
# Chandigarh                                 1185           1        100691
# Chhattisgarh                              14190           2       1187686
# Dadra and Nagar Haveli and Daman and Diu      4           0         11592
# Delhi                                     26665           8       2040788
# Goa*                                       4014           7        263313
#
#                                           new_cured  new_death
# state_name
# Andaman and Nicobar Islands                   10637        129  \
# Andhra Pradesh                              2325939      14733
# Arunachal Pradesh                             66750        296
# Assam                                        738108       8035
# Bihar                                        842945      12314
# Chandigarh                                    99505       1185
# Chhattisgarh                                1173494      14190
# Dadra and Nagar Haveli and Daman and Diu      11588          4
# Delhi                                       2014115      26665
# Goa*                                         259292       4014
#
#                                          death_reconsille total  state_code
# state_name
# Andaman and Nicobar Islands                                              35  \
# Andhra Pradesh                                                           28
# Arunachal Pradesh                                                        12
# Assam                                                                    18
# Bihar                                                                    10
# Chandigarh                                                                4
# Chhattisgarh                                                             22
# Dadra and Nagar Haveli and Daman and Diu                                 26
# Delhi                                                                     7
# Goa*                                                                     30
#
#                                           actualdeath24hrs
# state_name
# Andaman and Nicobar Islands                              0
# Andhra Pradesh                                           0
# Arunachal Pradesh                                        0
# Assam                                                    0
# Bihar                                                    0
# Chandigarh                                               0
# Chhattisgarh                                             0
# Dadra and Nagar Haveli and Daman and Diu                 0
# Delhi                                                    0
# Goa*                                                     0

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot
# Out:
# <Axes: ylabel='state_name'>

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death
# Out:
# <Axes: ylabel='state_name'>

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate
# Out:
# <Axes: ylabel='state_name'>

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "yellow"},figsize=(13,8))
# barplot for death cases and cured cases
# Out:
# <Axes: ylabel='state_name'>

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
# Out:
# <Axes: ylabel='state_name'>
